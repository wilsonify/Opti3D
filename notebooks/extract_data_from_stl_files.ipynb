# %%
import stl
from stl import mesh
from mpl_toolkits import mplot3d
from matplotlib import pyplot

# Create a new plot
figure = pyplot.figure()
axes = mplot3d.Axes3D(figure)

# Load the STL files and add the vectors to the plot
your_mesh = mesh.Mesh.from_file('stl_files/cube.stl')
axes.add_collection3d(mplot3d.art3d.Poly3DCollection(your_mesh.vectors))

# Auto scale to the mesh size
scale = your_mesh.points.flatten(-1)
axes.auto_scale_xyz(scale, scale, scale)

# Show the plot to the screen
pyplot.show()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:15: DeprecationWarning: Non-string object detected for the array ordering. Please pass in 'C', 'F', 'A', or 'K' instead
#   from ipykernel import kernelapp as app

# %%
your_mesh.save('largecube.txt',mode=stl.Mode.ASCII)

# %%
volume, cog, inertia = your_mesh.get_mass_properties()

print("Volume                                  = {0}".format(volume))
print("Position of the center of gravity (COG) = {0}".format(cog))
print("Inertia matrix at expressed at the COG  = {0}".format(inertia[0,:]))
print("                                          {0}".format(inertia[1,:]))
print("                                          {0}".format(inertia[2,:]))
# Out:
# Volume                                  = 7.999998430411675
# Position of the center of gravity (COG) = [-6.33299380e-08 -2.48352575e-08  1.24175272e-09]
# Inertia matrix at expressed at the COG  = [5.33333243e+00 6.55652071e-08 1.88748056e-07]
#                                           [6.55652071e-08 5.33333219e+00 1.98682144e-07]
#                                           [1.88748056e-07 1.98682144e-07 5.33333180e+00]

# %%
[_ for _ in your_mesh.get_mass_properties()]
# Out:
# [7.999998430411675,
#  array([-6.33299380e-08, -2.48352575e-08,  1.24175272e-09]),
#  array([[5.33333243e+00, 6.55652071e-08, 1.88748056e-07],
#         [6.55652071e-08, 5.33333219e+00, 1.98682144e-07],
#         [1.88748056e-07, 1.98682144e-07, 5.33333180e+00]])]

# %%
your
